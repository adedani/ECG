# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_for = pd.read_csv("data.txt", index_col=0)

# %%
data = data_for.index
print(data)
data[3]
# Out:
# Int64Index([518, 506, 494, 483, 472, 462, 454, 446, 440, 434,
#             ...
#             469, 474, 479, 482, 485, 489, 491, 492, 493, 494],
#            dtype='int64', name='530', length=2482)
# 483

# %%
plt.scatter(range(2482), data)

# %%
data1 = data[0:100]
data2 = data[100:200]
data3 = data[200:300]
data4 = data[300:400]
data5 = data[400:500]
plt.scatter(range(100), data1)
plt.scatter(range(100), data2)
plt.scatter(range(100), data3)
plt.scatter(range(100), data4)
plt.scatter(range(100), data5)

# %%
for i in range(100):
    if data1[i] == data1.max():
        print (i)
        break
    i = i+1
# Out:
# 62

# %%
h = data2.max()
for a in range(100):
    if data2[a] == data2.max():
        print (a)
        break
    a = a+1
# Out:
# 64

# %%
diff = a - i
hr = diff * 60
print(hr)
# Out:
# 120

# %%
datahr = data1 + data2

# %%
import heartpy as hp
working_data, measures = hp.process(data, 100.0)
hp.plotter(working_data, measures)
# Out:
# C:\Users\rd\Anaconda3\envs\cpe4903\lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data_df = pd.read_csv("ecg.csv", index_col=0)
data_df = data_df.head(5)
y = len(data_df)
y=y*140
print(y)
# plt.figure(figsize = (20,5)) 
# plt.figure(figure.dpi == 100)

plt.rcParams.update({'figure.figsize':(20,5), 'figure.dpi':100})

plt.scatter(range(y), data_df) # scatter plot of the data
# Out:
# 700

# %%
# Read the excel data into a pandas dataframe
data_df = pd.read_csv("ecg.csv", index_col=0)
# Print the first 51 rows
data_clean = data_df.head(10)
print(data_clean)
y = len(data_clean)
y = y*140
print(y)
# plt.figure(figsize = (20,5)) 
# plt.figure(figure.dpi == 100)

plt.rcParams.update({'figure.figsize':(20,5), 'figure.dpi':100})

plt.scatter(range(y), data_clean) # scatter plot of the data
# Out:
#              -2.8272038  -3.7738969  -4.3497511  -4.376041  -3.4749863  \
# -0.11252183
# -1.100878     -3.996840   -4.285843   -4.506579  -4.022377   -3.234368
# -0.567088     -2.593450   -3.874230   -4.584095  -4.187449   -3.151462
#  0.490473     -1.914407   -3.616364   -4.318823  -4.268016   -3.881110
#  0.800232     -0.874252   -2.384761   -3.973292  -4.338224   -3.802422
# -1.507674     -3.574550   -4.478011   -4.408275  -3.321242   -2.105171
# -0.297161     -2.766635   -4.102185   -4.589669  -4.219357   -3.650443
#  0.446769     -1.507397   -3.187468   -4.507462  -4.604201   -3.636115
#  0.087631     -1.753490   -3.304473   -4.704657  -4.686415   -3.611817
# -0.832281     -1.700368   -2.257301   -2.853671  -2.853301   -2.701487
#  0.084430     -3.190307   -4.686175   -4.559483  -4.087972   -2.618859
#
#              -2.1814082  -1.8182865  -1.2505219  -0.47749208  -0.36380791  \
# -0.11252183
# -1.100878     -1.566126   -0.992258   -0.754680     0.042321     0.148951
# ...
